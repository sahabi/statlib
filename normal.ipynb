# %%
from statlib import trasform_data, stat_report, prep_tree_tr, train, plot_dist, plot_cond_dist
import itertools
import pandas as pd
import numpy as np
from sklearn import preprocessing, svm, cross_validation
from sklearn.tree import DecisionTreeRegressor
from math import ceil
from scipy.stats import ttest_ind
data = '~/Documents/dataprojects/data/normal.csv'
students_df = pd.read_csv(data,sep=' ')
#students_df = trasform_data(students_df)    
enc = preprocessing.OneHotEncoder()
#X = students_df.drop(['Class'],1)
#X = prep_tree_tr(X,enc)
#Y = students_df['Class'].as_matrix()
#tree = DecisionTreeRegressor()
#(tree,score) = train(X,Y,tree)
#stat_report(students_df)
#print score
#print tree
print stat_report(students_df)
# Out:
# {'X3 and X5': 'correlation: 0.000819276977622    p-value: 0.993545370606', 'X2 and X3': 'correlation: 0.175105836776    p-value: 0.0814151622644', 'X2 and X4': 'correlation: 0.135189539488    p-value: 0.179899622273', 'X2 and X5': 'correlation: -0.0134694535802    p-value: 0.894187757454', 'X1 and X3': 'correlation: -0.0926405930092    p-value: 0.359283030947', 'X1 and X2': 'correlation: 0.0515689605874    p-value: 0.610370017552', 'X1 and X5': 'correlation: -0.119895997195    p-value: 0.234763434924', 'X1 and X4': 'correlation: 0.225930383505    p-value: 0.023808356726', 'X4 and X5': 'correlation: 0.101103265874    p-value: 0.31688051283', 'X3 and X4': 'correlation: 0.0146340081583    p-value: 0.885099382017'}
# /home/sahabi/miniconda/envs/data/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
# ...

# %%
students_df.as_matrix().reshape(students_df.as_matrix().size)
# Out:
# array([ -1.27600000e+00,  -1.21800000e+00,  -4.53000000e-01,
#         -3.50000000e-01,   7.23000000e-01,   6.76000000e-01,
#         -1.09900000e+00,  -3.14000000e-01,  -3.94000000e-01,
#         -6.33000000e-01,  -3.18000000e-01,  -7.99000000e-01,
#         -1.66400000e+00,   1.39100000e+00,   3.82000000e-01,
#          7.33000000e-01,   6.53000000e-01,   2.19000000e-01,
#         -6.81000000e-01,   1.12900000e+00,  -1.37700000e+00,
#         -1.25700000e+00,   4.95000000e-01,  -1.39000000e-01,
#         -8.54000000e-01,   4.28000000e-01,  -1.32200000e+00,
#         -3.15000000e-01,  -7.32000000e-01,  -1.34800000e+00,
#          2.33400000e+00,  -3.37000000e-01,  -1.95500000e+00,
#         -6.36000000e-01,  -1.31800000e+00,  -4.33000000e-01,
#          5.45000000e-01,   4.28000000e-01,  -2.97000000e-01,
#          2.76000000e-01,  -1.13600000e+00,   6.42000000e-01,
#          3.43600000e+00,  -1.66700000e+00,   8.47000000e-01,
# ...

# %%
data = '~/Documents/dataprojects/data/normal.csv'
students_df = pd.read_csv(data,sep=' ')

# %%
students_df
# Out:
#        X1     X2     X3     X4     X5
# 0  -1.276 -1.218 -0.453 -0.350  0.723
# 1   0.676 -1.099 -0.314 -0.394 -0.633
# 2  -0.318 -0.799 -1.664  1.391  0.382
# 3   0.733  0.653  0.219 -0.681  1.129
# 4  -1.377 -1.257  0.495 -0.139 -0.854
# 5   0.428 -1.322 -0.315 -0.732 -1.348
# 6   2.334 -0.337 -1.955 -0.636 -1.318
# 7  -0.433  0.545  0.428 -0.297  0.276
# 8  -1.136  0.642  3.436 -1.667  0.847
# 9  -1.173 -0.355  0.035  0.359  0.930
# 10  0.414 -0.011  0.666 -1.132 -0.410
# 11 -1.077  0.734  1.484 -0.340  0.789
# 12 -0.494  0.364 -1.237 -0.044 -0.111
# 13 -0.210  0.931  0.616 -0.377 -0.433
# 14  1.048  0.037  0.759  0.609 -2.043
# 15 -0.290  0.404 -0.543  0.486  0.869
# 16  0.347  2.816 -0.464 -0.632 -1.614
# 17  0.372 -0.074 -0.916  1.314 -0.038
# 18  0.637  0.563 -0.107  0.131 -1.808
# 19 -1.126  0.379  0.610 -0.364 -2.626
# 20  2.176  0.393 -0.924  1.911 -1.040
# 21 -1.168  0.485  0.076 -0.769  1.607
# 22 -1.185 -0.944 -1.604  0.185 -0.258
# 23 -0.300 -0.591 -0.545  0.018 -0.485
# ...

# %%
students_df
# Out:
#        X1     X2     X3     X4     X5
# 0  -1.276 -1.218 -0.453 -0.350  0.723
# 1   0.676 -1.099 -0.314 -0.394 -0.633
# 2  -0.318 -0.799 -1.664  1.391  0.382
# 3   0.733  0.653  0.219 -0.681  1.129
# 4  -1.377 -1.257  0.495 -0.139 -0.854
# 5   0.428 -1.322 -0.315 -0.732 -1.348
# 6   2.334 -0.337 -1.955 -0.636 -1.318
# 7  -0.433  0.545  0.428 -0.297  0.276
# 8  -1.136  0.642  3.436 -1.667  0.847
# 9  -1.173 -0.355  0.035  0.359  0.930
# 10  0.414 -0.011  0.666 -1.132 -0.410
# 11 -1.077  0.734  1.484 -0.340  0.789
# 12 -0.494  0.364 -1.237 -0.044 -0.111
# 13 -0.210  0.931  0.616 -0.377 -0.433
# 14  1.048  0.037  0.759  0.609 -2.043
# 15 -0.290  0.404 -0.543  0.486  0.869
# 16  0.347  2.816 -0.464 -0.632 -1.614
# 17  0.372 -0.074 -0.916  1.314 -0.038
# 18  0.637  0.563 -0.107  0.131 -1.808
# 19 -1.126  0.379  0.610 -0.364 -2.626
# 20  2.176  0.393 -0.924  1.911 -1.040
# 21 -1.168  0.485  0.076 -0.769  1.607
# 22 -1.185 -0.944 -1.604  0.185 -0.258
# 23 -0.300 -0.591 -0.545  0.018 -0.485
# ...
