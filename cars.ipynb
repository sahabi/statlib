# %%
from statlib import trasform_data, stat_report, prep_tree_tr, train
import itertools
import pandas as pd
import numpy as np
from sklearn import preprocessing, svm, cross_validation
from sklearn.tree import DecisionTreeRegressor
from math import ceil
from scipy.stats import ttest_ind
data = '~/Documents/dataprojects/data/cars.csv'
students_df = pd.read_csv(data,sep=',')
students_df = trasform_data(students_df)    
enc = preprocessing.OneHotEncoder()
X = students_df.drop(['Class'],1)
X = prep_tree_tr(X,enc)
Y = students_df['Class'].as_matrix()
tree = DecisionTreeRegressor()
(tree,score) = train(X,Y,tree)
print stat_report(students_df)
print score
print tree
# Out:
# {'maint and lug_boot': 'correlation: 0.0    p-value: 1.0', 'maint and safety': 'correlation: 0.0    p-value: 1.0', 'buying and lug_boot': 'correlation: 0.0    p-value: 1.0', 'buying and safety': 'correlation: 0.0    p-value: 1.0', 'maint and Class': 'correlation: 0.0401936463213    p-value: 0.0948631057388', 'persons and safety': 'correlation: 0.0    p-value: 1.0', 'buying and maint': 'correlation: 0.0    p-value: 1.0', 'persons and Class': 'correlation: -0.299468297819    p-value: 3.87673986266e-37', 'lug_boot and safety': 'correlation: 0.0    p-value: 1.0', 'maint and doors': 'correlation: 0.0    p-value: 1.0', 'buying and doors': 'correlation: 0.0    p-value: 1.0', 'maint and persons': 'correlation: 0.0    p-value: 1.0', 'doors and persons': 'correlation: 0.0    p-value: 1.0', 'doors and Class': 'correlation: -0.0313274008093    p-value: 0.193041968162', 'doors and safety': 'correlation: 0.0    p-value: 1.0', 'buying and Class': 'correlation: 0.0514242239699    p-value: 0.0325547215498', 'safety and Class': 'correlation: -0.0210437182251    p-value: 0.381990430378', 'persons and lug_boot': 'correlation: 0.0    p-value: 1.0', 'doors and lug_boot': 'correlation: 0.0    p-value: 1.0', 'lug_boot and Class': 'correlation: 0.0331843248934    p-value: 0.167947786176', 'buying and persons': 'correlation: 0.0    p-value: 1.0'}
# 0.856755611194
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
data
# Out:
# '~/Documents/dataprojects/data/cars.csv'

# %%
students_df
# Out:
#       buying  maint  doors  persons  lug_boot  safety  Class
# 0          3      3      0        0         2       1      2
# 1          3      3      0        0         2       2      2
# 2          3      3      0        0         2       0      2
# 3          3      3      0        0         1       1      2
# 4          3      3      0        0         1       2      2
# 5          3      3      0        0         1       0      2
# 6          3      3      0        0         0       1      2
# 7          3      3      0        0         0       2      2
# 8          3      3      0        0         0       0      2
# 9          3      3      0        1         2       1      2
# 10         3      3      0        1         2       2      2
# 11         3      3      0        1         2       0      2
# 12         3      3      0        1         1       1      2
# 13         3      3      0        1         1       2      2
# 14         3      3      0        1         1       0      2
# 15         3      3      0        1         0       1      2
# 16         3      3      0        1         0       2      2
# 17         3      3      0        1         0       0      2
# 18         3      3      0        2         2       1      2
# 19         3      3      0        2         2       2      2
# 20         3      3      0        2         2       0      2
# 21         3      3      0        2         1       1      2
# 22         3      3      0        2         1       2      2
# 23         3      3      0        2         1       0      2
# 24         3      3      0        2         0       1      2
# 25         3      3      0        2         0       2      2
# 26         3      3      0        2         0       0      2
# 27         3      3      1        0         2       1      2
# 28         3      3      1        0         2       2      2
# 29         3      3      1        0         2       0      2
# ...      ...    ...    ...      ...       ...     ...    ...
# 1698       1      1      2        2         0       1      2
# 1699       1      1      2        2         0       2      1
# 1700       1      1      2        2         0       0      3
# 1701       1      1      3        0         2       1      2
# 1702       1      1      3        0         2       2      2
# 1703       1      1      3        0         2       0      2
# 1704       1      1      3        0         1       1      2
# 1705       1      1      3        0         1       2      2
# 1706       1      1      3        0         1       0      2
# 1707       1      1      3        0         0       1      2
# 1708       1      1      3        0         0       2      2
# 1709       1      1      3        0         0       0      2
# 1710       1      1      3        1         2       1      2
# 1711       1      1      3        1         2       2      0
# 1712       1      1      3        1         2       0      1
# 1713       1      1      3        1         1       1      2
# 1714       1      1      3        1         1       2      1
# 1715       1      1      3        1         1       0      3
# 1716       1      1      3        1         0       1      2
# 1717       1      1      3        1         0       2      1
# 1718       1      1      3        1         0       0      3
# 1719       1      1      3        2         2       1      2
# 1720       1      1      3        2         2       2      0
# 1721       1      1      3        2         2       0      1
# 1722       1      1      3        2         1       1      2
# 1723       1      1      3        2         1       2      1
# 1724       1      1      3        2         1       0      3
# 1725       1      1      3        2         0       1      2
# 1726       1      1      3        2         0       2      1
# 1727       1      1      3        2         0       0      3
#
# [1728 rows x 7 columns]
